# %% [markdown]
# <a href="https://colab.research.google.com/github/vickykumar88888888/Calculating-Free-to-Paid-Conversion-Rate-with-SQL-and-Python/blob/main/360_project_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
drive_path = '/content/drive/My Drive/Maven'
os.listdir(drive_path,)
# Out:
# ['PowerBIforBusinessIntelligence-230523-122009.pdf',
#  'AdventureWorksPBIXFiles-230523-122034.zip',
#  'AdventureWorksRawData-230523-122034 (1).zip',
#  'AdventureWorksImages-230523-122034.zip',
#  'Part3.csv']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

sns.set(font_scale=1.0)

# %%
data = pd.read_csv('/content/drive/My Drive/Maven/Part3.csv')

# %%
diff_1 = data['days_diff_reg_watch']
diff_2 = data['days_diff_watch_purch'].dropna()

# %%
sns.kdeplot(data = diff_1)
# Out:
# <Axes: xlabel='days_diff_reg_watch', ylabel='Density'>

# %%
sns.kdeplot(data = diff_2)
# Out:
# <Axes: xlabel='days_diff_watch_purch', ylabel='Density'>

# %%
print(f'Mean:\t {diff_1.mean()}')
print(f'Median:\t {diff_1.median()}')
print(f'Mode:\t {list(diff_1.mode())[0]}')
# Out:
# Mean:	 3.4238953344853122
# Median:	 0.0
# Mode:	 0

# %%
print(f'Mean:\t {diff_2.mean()}')
print(f'Median:\t {diff_2.median()}')
print(f'Mode:\t {list(diff_2.mode())[0]}')
# Out:
# Mean:	 26.247156605424323
# Median:	 1.0
# Mode:	 0.0
